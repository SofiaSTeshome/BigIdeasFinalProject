# %%
import pandas as pd
data = pd.read_csv("DailyAQI.csv")

# %%
grouped=data.groupby('site')['index_value']
mean=grouped.mean()
fixed=mean.drop(['Lawrenceville 2', 'Liberty 2'])
print(fixed)
# Out:
# site
# Avalon                   25.293533
# Clairton                 29.862301
# Flag Plaza                9.949275
# Glassport High Street    17.308576
# Harrison Township        25.006569
# Lawrenceville            37.359295
# Liberty                  17.532591
# Lincoln                  35.108002
# North Braddock           19.172835
# Parkway East             21.508974
# Pittsburgh               24.697092
# South Fayette            25.125087
# West Mifflin              6.335548
# Name: index_value, dtype: float64

# %%
fixed.sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='site'>
