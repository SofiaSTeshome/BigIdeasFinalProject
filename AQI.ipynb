# %%
import pandas as pd
data = pd.read_csv("DailyAQI.csv")

# %%
grouped=data.groupby('site')['index_value']
mean=grouped.mean()
print(mean)
# Out:
# site
# Avalon                   25.293533
# Clairton                 29.862301
# Flag Plaza                9.949275
# Glassport High Street    17.308576
# Harrison Township        25.006569
# Lawrenceville            37.359295
# Lawrenceville 2           3.019053
# Liberty                  17.532591
# Liberty 2                31.921265
# Lincoln                  35.108002
# North Braddock           19.172835
# Parkway East             21.508974
# Pittsburgh               24.697092
# South Fayette            25.125087
# West Mifflin              6.335548
# Name: index_value, dtype: float64

# %% [markdown]
# Corrected:

# %% [markdown]
# Avalon                   25.293533
# Clairton                 29.862301
# Flag Plaza                9.949275
# Glassport High Street    17.308576
# Harrison Township        25.006569
# Lawrenceville            20.189174
# Liberty                  24.726928
# Lincoln                  35.108002
# North Braddock           19.172835
# Parkway East             21.508974
# Pittsburgh               24.697092
# South Fayette            25.125087
# West Mifflin              6.335548

# %%
mean.sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='site'>

# %% [markdown]
# Best AQI:
# 1. West Mifflin
# 2. Flag Plaza
# 3. Glassport High Street
# 4. North Braddock
# 5. Lawrenceville
