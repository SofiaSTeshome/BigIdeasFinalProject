# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
data = pd.read_csv("CrimeRate1977.csv")

# %%
groups=data.groupby('neighborhood')[['number_major_crimes_1973', 'neighborhood_crime_rate_1973', 'number_major_crimes_1974', 'neighborhood_crime_rate_1974', 'number_major_crimes_1975', 'neighborhood_crime_rate_1975']]
groups.mean()
# Out:
#                         number_major_crimes_1973  \
# neighborhood
# 31st ward                                  125.0
# Allegheny Center                           277.0
# Allegheny West                             154.0
# Allentown                                  117.0
# Arlington                                  243.0
# ...                                          ...
# Troy Hill                                   75.0
# Uptown                                     323.0
# West End                                    70.0
# Westwood                                    65.0
# Woods Run- Halls Grove                      51.0
#
#                         neighborhood_crime_rate_1973  \
# neighborhood
# 31st ward                                      0.017
# Allegheny Center                               0.151
# Allegheny West                                 0.147
# Allentown                                      0.026
# Arlington                                      0.037
# ...                                              ...
# Troy Hill                                      0.019
# Uptown                                         0.099
# West End                                       0.049
# Westwood                                       0.019
# Woods Run- Halls Grove                         0.020
#
#                         number_major_crimes_1974  \
# neighborhood
# 31st ward                                   85.0
# Allegheny Center                           407.0
# Allegheny West                             197.0
# Allentown                                   80.0
# Arlington                                  177.0
# ...                                          ...
# Troy Hill                                   55.0
# Uptown                                     382.0
# West End                                    70.0
# Westwood                                    46.0
# Woods Run- Halls Grove                      58.0
#
#                         neighborhood_crime_rate_1974  \
# neighborhood
# 31st ward                                      0.012
# Allegheny Center                               0.222
# Allegheny West                                 0.188
# Allentown                                      0.018
# Arlington                                      0.027
# ...                                              ...
# Troy Hill                                      0.014
# Uptown                                         0.117
# West End                                       0.049
# Westwood                                       0.014
# Woods Run- Halls Grove                         0.023
#
#                         number_major_crimes_1975  neighborhood_crime_rate_1975
# neighborhood
# 31st ward                                   92.0                         0.013
# Allegheny Center                           571.0                         0.312
# Allegheny West                             227.0                         0.217
# Allentown                                  114.0                         0.025
# Arlington                                  184.0                         0.028
# ...                                          ...                           ...
# Troy Hill                                   61.0                         0.016
# Uptown                                     409.0                         0.126
# West End                                    60.0                         0.040
# Westwood                                    78.0                         0.023
# Woods Run- Halls Grove                      40.0                         0.016
#
# [69 rows x 6 columns]

# %%
means = groups.mean()
years = [1973, 1974, 1975]
crime_rates = means[['neighborhood_crime_rate_1973', 'neighborhood_crime_rate_1974', 'neighborhood_crime_rate_1975']].mean()

plt.plot(years, crime_rates, marker='o')
plt.xlabel('Year')
plt.ylabel('Average Crime Rate')
plt.title('Average Crime Rate Over Time')
plt.grid(True)
plt.show()

# %%
# Out:
# neighborhood_crime_rate_1973    0.059304
# neighborhood_crime_rate_1974    0.068507
# neighborhood_crime_rate_1975    0.080290
# dtype: float64
